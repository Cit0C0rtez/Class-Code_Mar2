# %%
import pandas as pd

data = [{"a": 2, "b": 3}, {"a": 2, "b": 6}]

df = pd.DataFrame(data)

# %%
df['a'].max()
# Out:
# 2

# %%
df.index = ["a", "b"]

df.index
# Out:
# Index(['a', 'b'], dtype='object')

# %%
df.loc["b"]
# Out:
# a    2
# b    6
# Name: b, dtype: int64

# %%
import pandas as pd

class_data = pd.read_csv('Class data - Sheet1.csv')

df = pd.DataFrame(class_data)

df
# Out:
#       Person        State     Age  Shoe size         Sign   \
# 0        Abe           CO      38        9.5         virgo
# 1     Andrew           CO      20       12.0           leo
# 2     Nardos           CO      21        NaN   Sagittarius
# 3     Carson           CO      22       12.0      Capricon
# 4    Patrick           MA      21        9.5       Scorpio
# 5    Timothy           CA      22       10.0       Scorpio
# 6       Owen           MT      21       10.0        Cancer
# 7      Lucas           CO      20       11.0        Taurus
# 8     Sylvia           CO      22        7.0       Scorpio
# 9     Hannah           CO      20        7.5         Aries
# 10   Charlie           CO      21        9.5      Capricon
# 11   Vincent           CO      20       13.0         Aries
# 12        JP           CO      21       10.0        Cancer
# 13     Lucas           NV      20       11.5        Taurus
# 14   William           CA      22        NaN         Libra
# ...

# %%
sorted_shoesize = df.sort_values(by = ['Shoe size'], ascending = False)

a = sorted_shoesize.max().reset_index()

a
# Out:
# <ipython-input-85-792ae0f13fd1>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a = sorted_shoesize.max().reset_index()
#        index       0
# 0        Age  Senior
# 1  Shoe size    15.0
